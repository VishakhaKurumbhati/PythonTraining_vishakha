# %%
# KNN => 1. https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# Iris Data => https://www.kaggle.com/datasets/uciml/iris


# Activity

# 1. Understand the data
# 2. Plot graphs like scatterplots, heat maps to visualize it
# 3. train the model (with different values of k)
# 4. test it
# 5. measure the model accuracy using score, confusion matrix etc
# 6. Compare the model's performance against other clasification techniques like LR, NB etc
